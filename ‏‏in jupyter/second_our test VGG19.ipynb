# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.vgg19 import preprocess_input

from tensorflow.keras.preprocessing.image import load_img 
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
labels = {
    0: 'dress',
    1: 'hat',
    2: 'longsleeve',
    3: 'outwear',
    4: 'pants',
    5: 'shirt',
    6: 'shoes',
    7: 'shorts',
    8: 'skirt',
    9: 't-shirt'
}

# %%
image_size = (224, 224)

# %%
model = keras.models.load_model('VGG19_v1_09_0.842.h5')

# %%
path = r'C:\Users\Zainon\Desktop\clothes classification with VGG19 model\clothing-dataset-small-master\test\pants\7d3a88e9-2fb3-4044-bdb2-5bbdf66d8a1b.jpg'
img = load_img(path, target_size=(image_size))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x = np.array(img)
X = np.array([x])
X = preprocess_input(X)

# %%
pred = model.predict(X)
pred[0]
# Out:
# 1/1 [==============================] - 1s 928ms/step
# array([-0.05545057, -3.3975441 , -0.3086263 , -4.7744503 , 13.509048  ,
#        -1.691448  , -7.630231  ,  4.948354  ,  4.929446  , -2.657062  ],
#       dtype=float32)

# %%
pred[0].argmax()
# Out:
# 4

# %%
labels[pred[0].argmax()]
# Out:
# 'pants'

# %%
test_gen = ImageDataGenerator(preprocessing_function=preprocess_input)

test_ds = test_gen.flow_from_directory(
    r"C:\Users\Zainon\Desktop\clothes classification with VGG19 model\clothing-dataset-small-master\test",
    shuffle=False,
    target_size=image_size,
    batch_size=32,
)
# Out:
# Found 372 images belonging to 10 classes.

# %%
model.evaluate(test_ds)
# Out:
# 12/12 [==============================] - 74s 6s/step - loss: 0.5255 - accuracy: 0.8495
# [0.5254613757133484, 0.8494623899459839]

# %%
path = r'C:\Users\Zainon\Desktop\clothes classification with VGG19 model\٢٠٢٢١٢٣١_٢٢٢٥٠٥.jpg'
img = load_img(path, target_size=(image_size))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x = np.array(img)
X = np.array([x])
X = preprocess_input(X)

# %%
pred = model.predict(X)
pred[0]
# Out:
# 1/1 [==============================] - 0s 474ms/step
# array([ 4.341604  , -2.5692332 , -1.7652196 ,  0.56310874, -3.1277127 ,
#         4.2702417 , -6.8581576 , -3.0904274 , -8.293247  ,  7.979919  ],
#       dtype=float32)

# %%
pred[0].argmax()
# Out:
# 9

# %%
labels[pred[0].argmax()]
# Out:
# 't-shirt'
